# %%
#Description: this program will check the similarity between a resume and a job description

# %%
#Install the docx2txt package
# !pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3957 sha256=b034f9669c9967b044943cbd8d6ccb85a91e9fad51b248a22a1ed69d2c1749b4
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
#Import the library
import docx2txt

# %%
#Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09503557-1923-4d56-996d-b99682508c48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09503557-1923-4d56-996d-b99682508c48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Store the resume in a variable
resume = docx2txt.process("cv1.docx")

# Print the resume
print(resume)
# Out:
# CHARLES MCTURLAND SOFTWARE ENGINEER
#
# CONTACT
#
# cmcturland@email.com (123) 456-7890
#
# New York, NY
#
# LinkedIn
#
# EDUCATION
#
# B.S.
#
# Computer Science
#
# University ofPittsburgh September 2008 - April 2012 Pittsburgh, PA
#
# SKILLS
#
# Python (Django)
#
# Javascript (NodeJS ReactJS, jQuery)
#
# SQL (MySQL, PostgreSQL, NoSQL)
#
# HTML5/CSS
#
# AWS
#
# Unix, Git
#
# PROJECTS
#
# Poker Simulation
#
# Built a full-stack web app to allow users to simulate and visualize outcomes of poker hands against opponents of different play styles using open source cards.js on the front-end
#
# Utilized sci-kit learn in Python to simulate possible outcomes under different scenarios that the user chose
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# WORK EXPERIENCE
#
# Software Engineer
#
# Embark
#
# January 2015 - current / NewYork, NY
#
# ...

# %%
import csv

# Load the job ads from the CSV file
job_ads = []
with open('ads_data_cleaned.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the first row
    for row in reader:
        job_ads.append(row[2])  # the job description are in the first column
print(job_ads)
# Out:
# ['Job Description', 'We are seeking a highly motivated and skilled individual to join our team as an Entry-Level Software Engineer. This position is ideal for someone with foundational knowledge and experience in Java development, looking to grow their career as a software engineer. As an Entry-Level Software Engineer, you will collaborate with a team of experienced developers to design, develop, test, and maintain software solutions. This is a great opportunity to apply your Java skills and expand your expertise in software engineering.\nResponsibilities:\nCollaborate with the development team to understand user requirements and translate them into software solutions.\nDesign, develop, and test software applications using Java and other relevant technologies.', 'Software Dev Engineer II (Hybrid)\nNew Journey AI/Genesis10 is seeking a Software Engineer for a contract position supporting our Global eCommerce client.\nPay: $57.00-$58.00/hour W2\nLocation: Seattle, WA (Hybrid – 3 days o
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Prepare the list for storing similarity scores
similarity_scores = []
# Calculate the similarity for each job ad
for job_ad in job_ads:
    # Create a list of resume and current job ad
    text = [resume, job_ad]
    # Perform count vectorization and similarity calculation
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(text)
    similarity_score = cosine_similarity(count_matrix)[0][1]
    similarity_scores.append(similarity_score)

# %%
# Print the similarity scores for each job ad
for i, score in enumerate(similarity_scores):
    match_percentage = round(score * 100, 2)
    print("Job Ad {} matches about {}% of the resume.".format(i+1, match_percentage))
# Out:
# Job Ad 1 matches about 0.0% of the resume.
# Job Ad 2 matches about 41.07% of the resume.
# Job Ad 3 matches about 31.75% of the resume.
# Job Ad 4 matches about 0.0% of the resume.
# Job Ad 5 matches about 42.52% of the resume.
# Job Ad 6 matches about 37.24% of the resume.
# Job Ad 7 matches about 41.34% of the resume.
# Job Ad 8 matches about 41.8% of the resume.
# Job Ad 9 matches about 45.71% of the resume.
# Job Ad 10 matches about 33.36% of the resume.
# Job Ad 11 matches about 45.52% of the resume.
# Job Ad 12 matches about 0.0% of the resume.
# Job Ad 13 matches about 16.69% of the resume.
# Job Ad 14 matches about 0.0% of the resume.
# Job Ad 15 matches about 35.74% of the resume.
# Job Ad 16 matches about 0.0% of the resume.
# Job Ad 17 matches about 50.91% of the resume.
# Job Ad 18 matches about 36.72% of the resume.
# Job Ad 19 matches about 48.29% of the resume.
# Job Ad 20 matches about 35.44% of the resume.
# Job Ad 21 matches about 44.29% of the resume.
# ...
